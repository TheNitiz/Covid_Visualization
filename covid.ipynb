# %%
from bs4 import BeautifulSoup as soup #Beautiful Soup is a Python library for pulling data out of HTML and XML files.
import requests #for request to the server

# %%
import pandas as pd
import numpy as np
import gc #Python has an automated garbage collection. It has an algorithm to deallocate objects which are no longer needed.
import plotly.graph_objects as go
import plotly.express as px

# %% [markdown]
# ## Data Collection
# ### Web Scrapping:

# %%
#lxml is a Python library which allows for easy handling of XML and HTML files, and can also be used for web scraping.
url = "https://www.worldometers.info/coronavirus/#countries"
res = requests.get(url)
page = soup(res.text, 'lxml')

# %%
table = page.select('#main_table_countries_yesterday')
row_data = table[0].findAll("tr",{"style":""})
title = row_data[0]
del row_data[0]
data = []
clean = True
for country in row_data:
    country_data = []
    country_container = country.select("td")
    
    if country_container[1].text == "China":
        continue
    for i in range(1, len(country_container)):
        final_feature = country_container[i].text
        if clean:
            if i != 1 and i != len(country_container)-1:
                final_feature = final_feature.replace(",","")
                if final_feature.find('+') != -1:
                    final_feature = final_feature.replace("+","")
                    final_feature = float(final_feature)
            
                elif final_feature.find("-") != -1:
                    final_feature = final_feature.replace("-","")
                    final_feature = float(final_feature)*-1
        if final_feature == "N/A":
            final_feature = 0
        elif final_feature == "" or final_feature == " ":
            final_feature = -1
            
        country_data.append(final_feature)
        
    data.append(country_data)

# %% [markdown]
# ## Data PreProcessing

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#         0          1        2                                        3
# 0    World  685610942  57123.0                                  6842383  \
# 1      USA  106464679   1098.0  1158158
# 2    India   44818115  10093.0   531114
# 3   France   39896203   8595.0   166024
# 4  Germany   38382386     -1.0   171992
#
#       4          5        6         7      8       9   ...          11
# 0  156.0  658326986  60386.0  20441573  39507   87957  ...          -1  \
# 1    8.0  104311698   9159.0    994823   1636  317990  ...  1175946071
# 2   23.0   44229459   6248.0     57542      0   31862  ...   923877832
# 3   -1.0   39592740   6103.0    137439    869  608317  ...   271490188
# 4   -1.0   38149200   1200.0     61194      0  457567  ...   122332384
#
#         12           13             14  15    16  17   18    19     20
# 0       -1           -1            All  \n    -1  -1   -1    -1     -1
# 1  3512328   334805269   North America   3   289   0    3  0.02  2,971
# 2   656801  1406631776            Asia  31  2648   2    7  0.02     41
# 3  4139547    65584518          Europe   2   395   0  131    -1  2,096
# 4  1458359    83883596          Europe   2   488   1   -1    -1    730
#
# [5 rows x 21 columns]

# %%
column_labels = ["Country", "Total_Cases", "New_Cases", "Total_Deaths", "New_Deaths", "Total_Recovered", "New_Recovered", "Active_Cases", "Serious", "Tot Cases/ 1M ppl", "Deaths/ 1M ppl", "Total_Tests", "Tests/ 1M ppl", "Population", "Continent"]
len(column_labels)
# Out:
# 15

# %%
df1 = df

# %%
df1.drop([15,16,17,18,19,20], inplace=True, axis=1)

# %%
df1.columns = column_labels

# %%
df1.head()
# Out:
#    Country Total_Cases  New_Cases                             Total_Deaths
# 0    World   685610942    57123.0                                  6842383  \
# 1      USA   106464679     1098.0  1158158
# 2    India    44818115    10093.0   531114
# 3   France    39896203     8595.0   166024
# 4  Germany    38382386       -1.0   171992
#
#    New_Deaths Total_Recovered  New_Recovered Active_Cases Serious
# 0       156.0       658326986        60386.0     20441573   39507  \
# 1         8.0       104311698         9159.0       994823    1636
# 2        23.0        44229459         6248.0        57542       0
# 3        -1.0        39592740         6103.0       137439     869
# 4        -1.0        38149200         1200.0        61194       0
#
#   Tot Cases/ 1M ppl Deaths/ 1M ppl Total_Tests Tests/ 1M ppl   Population
# 0             87957          877.8          -1            -1           -1  \
# 1            317990           3459  1175946071       3512328   334805269
# 2             31862            378   923877832        656801  1406631776
# 3            608317           2531   271490188       4139547    65584518
# 4            457567           2050   122332384       1458359    83883596
#
#        Continent
# 0            All
# 1  North America
# 2           Asia
# 3         Europe
# 4         Europe

# %% [markdown]
# #### Change Type of columns:

# %%
for label in df1.columns:
    if label != 'Country' and label != 'Continent':
        df1[label] = pd.to_numeric(df1[label])

# %% [markdown]
# #### Add New Columns:

# %%
df1['% Inc_Cases'] = df1['New_Cases']/df1['Total_Cases']*100
df1['% Inc_Deaths'] = df1['New_Deaths']/df1['Total_Deaths']*100
df1['% Inc_Recovered'] = df1['New_Recovered']/df1['Total_Recovered']*100

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Cases:

# %%
cases = df1[['Total_Recovered','Active_Cases','Total_Deaths']].loc[0]
# DataFrame.loc attribute access a group of rows and columns by label(s) or a boolean array in the given DataFrame.
# here loc[0] means to access the data from 0th row

# %%
cases
# Out:
# Total_Recovered    658326986
# Active_Cases        20441573
# Total_Deaths         6842383
# Name: 0, dtype: int64

# %%
cases_df = pd.DataFrame(cases).reset_index()
cases_df
# Out:
#              index          0
# 0  Total_Recovered  658326986
# 1     Active_Cases   20441573
# 2     Total_Deaths    6842383

# %%
cases_df.columns = ['Type','Total']
cases_df
# Out:
#               Type      Total
# 0  Total_Recovered  658326986
# 1     Active_Cases   20441573
# 2     Total_Deaths    6842383

# %%
cases_df['Percentage'] = np.round((cases_df['Total']/np.sum(cases_df['Total']))*100,2)

# %%
cases_df['Virus'] = ["COVID-19" for i in range(len(cases_df))]
cases_df
# Out:
#               Type      Total  Percentage     Virus
# 0  Total_Recovered  658326986       96.02  COVID-19
# 1     Active_Cases   20441573        2.98  COVID-19
# 2     Total_Deaths    6842383        1.00  COVID-19

# %% [markdown]
# #### Visualize Total Cases:

# %%
fig = px.bar(cases_df, x = "Virus", y = "Percentage", color = "Type", hover_data=["Total"])
fig.show()
# Out:
# <div>                            <div id="92db5982-32ec-4d07-9f57-1d008f713700" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92db5982-32ec-4d07-9f57-1d008f713700")) {                    Plotly.newPlot(                        "92db5982-32ec-4d07-9f57-1d008f713700",                        [{"alignmentgroup":"True","customdata":[[658326986]],"hovertemplate":"Type=Total_Recovered<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"Total_Recovered","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Total_Recovered","offsetgroup":"Total_Recovered","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[96.02],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[20441573]],"hovertemplate":"Type=Active_Cases<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"Active_Cases","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Active_Cases","offsetgroup":"Active_Cases","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[2.98],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[6842383]],"hovertemplate":"Type=Total_Deaths<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"Total_Deaths","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Total_Deaths","offsetgroup":"Total_Deaths","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[1.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f" ...

# %% [markdown]
# #### Visualize New Cases:

# %%
Newdata = df1[['New_Cases','New_Recovered','New_Deaths']].loc[0]
newcasedf = pd.DataFrame(Newdata).reset_index()
newcasedf.columns = ['Type','Total']
newcasedf['Percentage'] = np.round((newcasedf['Total']/np.sum(newcasedf['Total']))*100,2)
newcasedf['Virus'] = ['COVID-19' for i in range(len(newcasedf))]
fig = px.bar(newcasedf, x="Virus", y="Percentage", color="Type", hover_data=["Total"])
fig.show()
# Out:
# <div>                            <div id="3672d199-011c-4de4-b6bd-9cc427f281b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3672d199-011c-4de4-b6bd-9cc427f281b4")) {                    Plotly.newPlot(                        "3672d199-011c-4de4-b6bd-9cc427f281b4",                        [{"alignmentgroup":"True","customdata":[[57123.0]],"hovertemplate":"Type=New_Cases<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"New_Cases","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"New_Cases","offsetgroup":"New_Cases","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[48.55],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[60386.0]],"hovertemplate":"Type=New_Recovered<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"New_Recovered","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"New_Recovered","offsetgroup":"New_Recovered","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[51.32],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[156.0]],"hovertemplate":"Type=New_Deaths<br>Virus=%{x}<br>Percentage=%{y}<br>Total=%{customdata[0]}<extra></extra>","legendgroup":"New_Deaths","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"New_Deaths","offsetgroup":"New_Deaths","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[0.13],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8" ...

# %%
df1.columns
# Out:
# Index(['Country', 'Total_Cases', 'New_Cases', 'Total_Deaths', 'New_Deaths',
#        'Total_Recovered', 'New_Recovered', 'Active_Cases', 'Serious',
#        'Tot Cases/ 1M ppl', 'Deaths/ 1M ppl', 'Total_Tests', 'Tests/ 1M ppl',
#        'Population', 'Continent', '% Inc_Cases', '% Inc_Deaths',
#        '% Inc_Recovered'],
#       dtype='object')

# %%
per = np.round(df[["% Inc_Cases", "% Inc_Deaths", "% Inc_Recovered"]].loc[0], 2)
per_df = pd.DataFrame(per)
per_df.columns = ['Percentage']
fig = go.Figure()
fig.add_trace(go.Bar(x=per_df.index,y=per_df['Percentage'], marker_color=["Yellow", "blue", "red"]))
fig.show()
# Out:
# <div>                            <div id="2c815da8-cca3-47bd-9c0c-bcadfac758c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c815da8-cca3-47bd-9c0c-bcadfac758c0")) {                    Plotly.newPlot(                        "2c815da8-cca3-47bd-9c0c-bcadfac758c0",                        [{"marker":{"color":["Yellow","blue","red"]},"x":["% Inc_Cases","% Inc_Deaths","% Inc_Recovered"],"y":[0.01,0.0,0.01],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0, ...
#
# var gd = document.getElementById('2c815da8-cca3-47bd-9c0c-bcadfac758c0');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!'])

# %% [markdown]
# ### Visualize Continents:

# %%
continent_df = df1.groupby('Continent').sum().drop("All")
# drop "All" row

# %%
continent_df = continent_df.reset_index()
continent_df
# Out:
#            Continent                                            Country
# 0             Africa  South AfricaMoroccoTunisiaEgyptLibyaEthiopiaRé...  \
# 1               Asia  IndiaJapanS. KoreaTurkeyVietnamTaiwanIranIndon...
# 2  Australia/Oceania  AustraliaNew ZealandNew CaledoniaFrench Polyne...
# 3             Europe  FranceGermanyItalyRussiaSpainNetherlandsPoland...
# 4      North America  USAMexicoCanadaGuatemalaCosta RicaCubaPanamaDo...
# 5      South America  BrazilColombiaChilePeruBoliviaEcuadorUruguayPa...
#
#    Total_Cases  New_Cases  Total_Deaths  New_Deaths  Total_Recovered
# 0     12805489        6.0        258577       -56.0         10954562  \
# 1    210611304    34137.0       1534227        27.0        178159095
# 2     14084808      -17.0         26937       -20.0         13843889
# 3    223885190    19048.0       1825455        27.0        219752683
# 4    125972055     3142.0       1625744       -10.0        121501105
# 5     58405310      630.0       1222894       -12.0         55766970
#
#    New_Recovered  Active_Cases  Serious  Tot Cases/ 1M ppl  Deaths/ 1M ppl
# 0           66.0        377871      516          2488825.0         18491.0  \
# 1        20958.0      13570800     1637          7625593.0         34567.0
# 2          -15.0         86121       58          4639745.0          8847.0
# 3        26677.0       2025568     2678         18332202.0        122650.0
# 4        11790.0       1941259     1989          8712322.0         57675.0
# 5          792.0        544992     1483          1831633.0         30188.0
#
#    Total_Tests  Tests/ 1M ppl  Population  % Inc_Cases  % Inc_Deaths
# 0    110838308       10906548  1402440339    -0.204448     84.913851  \
# 1   2225039342       92907035  3217529895     0.246528     -8.670678
# 2     88580174       21050084    43470408   -20.249721     92.147470
# 3   2306362772      206717923   679045131     0.131406    -10.471199
# 4   1313452474       99161788   598087045    -0.208785   -110.557878
# 5    207917156       10727908   391680670     0.009221     -0.431678
#
#    % Inc_Recovered
# 0       -50.136054
# 1         0.275596
# 2       199.504774
# 3         0.322138
# 4        -0.310750
# 5         0.006716

# %%
def continent_visual(c_list):
    for label in c_list:
        c_df = continent_df[['Continent',label]]
        c_df['Percentage'] = np.round(c_df[label]/ np.sum(c_df[label]), 2)
        c_df['Virus'] = ["Covid-19" for i in range(len(c_df))]
        
        fig = px.bar(c_df, x="Virus", y="Percentage", color="Continent", hover_data=[label])
        fig.update_layout(title={"text":f"{label}"})
        fig.show()
        gc.collect()

# %%
cases_list = ["Total_Cases", "Active_Cases", "New_Cases", "Serious", "Tot Cases/ 1M ppl"]
death_list = ["Total_Deaths", "New_Deaths", "Deaths/ 1M ppl"]
recovered_list = ["Total_Recovered", "New_Recovered", "% Inc_Recovered"]

# %%
continent_visual(cases_list)
# Out:
# <div>                            <div id="9831e671-e152-4be5-b590-3992e7308f34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9831e671-e152-4be5-b590-3992e7308f34")) {                    Plotly.newPlot(                        "9831e671-e152-4be5-b590-3992e7308f34",                        [{"alignmentgroup":"True","customdata":[[12805489]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Total_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.02],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[210611304]],"hovertemplate":"Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Total_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.33],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[14084808]],"hovertemplate":"Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Total_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Australia/Oceania","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia/Oceania","offsetgroup":"Australia/Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.02],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[223885190]],"hovertemplate":"Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Total_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.35],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[125972055]],"hovertemplate":"Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Total_Cases=%{customdata[0]}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[58405310]],"hovertemplate":"Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Total_Cases=%{customdata[0]}<extra></extra>","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.09],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"tick ...
# <div>                            <div id="7212c462-b41a-4a27-b612-d69d813d33fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7212c462-b41a-4a27-b612-d69d813d33fd")) {                    Plotly.newPlot(                        "7212c462-b41a-4a27-b612-d69d813d33fd",                        [{"alignmentgroup":"True","customdata":[[377871]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Active_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.02],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[13570800]],"hovertemplate":"Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Active_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.73],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[86121]],"hovertemplate":"Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Active_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Australia/Oceania","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia/Oceania","offsetgroup":"Australia/Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[2025568]],"hovertemplate":"Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Active_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1941259]],"hovertemplate":"Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Active_Cases=%{customdata[0]}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[544992]],"hovertemplate":"Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Active_Cases=%{customdata[0]}<extra></extra>","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.03],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""}, ...
# <div>                            <div id="35718a11-3d57-48b2-9075-16b0db4a8b47" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35718a11-3d57-48b2-9075-16b0db4a8b47")) {                    Plotly.newPlot(                        "35718a11-3d57-48b2-9075-16b0db4a8b47",                        [{"alignmentgroup":"True","customdata":[[6.0]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>New_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[34137.0]],"hovertemplate":"Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>New_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-17.0]],"hovertemplate":"Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>New_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Australia/Oceania","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia/Oceania","offsetgroup":"Australia/Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[-0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[19048.0]],"hovertemplate":"Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>New_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.33],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[3142.0]],"hovertemplate":"Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>New_Cases=%{customdata[0]}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.06],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[630.0]],"hovertemplate":"Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>New_Cases=%{customdata[0]}<extra></extra>","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.01],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0 ...
# <div>                            <div id="60e53c58-7a4f-42e2-a8c7-87f67e157ba6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60e53c58-7a4f-42e2-a8c7-87f67e157ba6")) {                    Plotly.newPlot(                        "60e53c58-7a4f-42e2-a8c7-87f67e157ba6",                        [{"alignmentgroup":"True","customdata":[[516]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Serious=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.06],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1637]],"hovertemplate":"Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Serious=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[58]],"hovertemplate":"Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Serious=%{customdata[0]}<extra></extra>","legendgroup":"Australia/Oceania","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia/Oceania","offsetgroup":"Australia/Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.01],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[2678]],"hovertemplate":"Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Serious=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.32],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1989]],"hovertemplate":"Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Serious=%{customdata[0]}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1483]],"hovertemplate":"Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Serious=%{customdata[0]}<extra></extra>","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.18],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111111111 ...
# <div>                            <div id="fe77eaa1-6408-4e97-9182-4a96d4d3c2ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe77eaa1-6408-4e97-9182-4a96d4d3c2ca")) {                    Plotly.newPlot(                        "fe77eaa1-6408-4e97-9182-4a96d4d3c2ca",                        [{"alignmentgroup":"True","customdata":[[2488825.0]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/ 1M ppl=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.06],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[7625593.0]],"hovertemplate":"Continent=Asia<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/ 1M ppl=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.17],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[4639745.0]],"hovertemplate":"Continent=Australia/Oceania<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/ 1M ppl=%{customdata[0]}<extra></extra>","legendgroup":"Australia/Oceania","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Australia/Oceania","offsetgroup":"Australia/Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[18332202.0]],"hovertemplate":"Continent=Europe<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/ 1M ppl=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.42],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[8712322.0]],"hovertemplate":"Continent=North America<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/ 1M ppl=%{customdata[0]}<extra></extra>","legendgroup":"North America","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"North America","offsetgroup":"North America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1831633.0]],"hovertemplate":"Continent=South America<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/ 1M ppl=%{customdata[0]}<extra></extra>","legendgroup":"South America","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"South America","offsetgroup":"South America","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.04],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"hea ...

# %% [markdown]
# ### Visualize Countries:
# #### For all Countries:

# %%
df_countries = df1.groupby("Country").sum().drop('World')
df_countries = df_countries.reset_index()

# %%
df_countries.columns
# Out:
# Index(['Country', 'Total_Cases', 'New_Cases', 'Total_Deaths', 'New_Deaths',
#        'Total_Recovered', 'New_Recovered', 'Active_Cases', 'Serious',
#        'Tot Cases/ 1M ppl', 'Deaths/ 1M ppl', 'Total_Tests', 'Tests/ 1M ppl',
#        'Population', 'Continent', '% Inc_Cases', '% Inc_Deaths',
#        '% Inc_Recovered'],
#       dtype='object')

# %%
def continent_visual(c_list):
    for label in c_list:
        c_df = df_countries[["Country",label]]
        c_df['Percentage'] = np.round(c_df[label]/ np.sum(c_df[label]), 2)
        c_df['Virus'] = ["Covid-19" for i in range(len(c_df))]
        
        fig = px.bar(c_df, x="Virus", y="Percentage", color="Country", hover_data=[label])
        fig.update_layout(title={"text":f"{label}"})
        fig.show()
        gc.collect()

# %%
cases_list = ["Total_Cases", "Active_Cases", "New_Cases", "Serious", "Tot Cases/ 1M ppl"]
death_list = ["Total_Deaths", "New_Deaths", "Deaths/ 1M ppl"]
recovered_list = ["Total_Recovered", "New_Recovered", "% Inc_Recovered"]

# %%
continent_visual(cases_list)
# Out:
# <div>                            <div id="21f9ab4b-c638-4b8f-8c19-a2475a68a2cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21f9ab4b-c638-4b8f-8c19-a2475a68a2cf")) {                    Plotly.newPlot(                        "21f9ab4b-c638-4b8f-8c19-a2475a68a2cf",                        [{"alignmentgroup":"True","customdata":[[212605]],"hovertemplate":"Country=Afghanistan<br>Virus=%{x}<br>Percentage=%{y}<br>Total_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[334714]],"hovertemplate":"Country=Albania<br>Virus=%{x}<br>Percentage=%{y}<br>Total_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Albania","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Albania","offsetgroup":"Albania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[271642]],"hovertemplate":"Country=Algeria<br>Virus=%{x}<br>Percentage=%{y}<br>Total_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Algeria","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Algeria","offsetgroup":"Algeria","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[47939]],"hovertemplate":"Country=Andorra<br>Virus=%{x}<br>Percentage=%{y}<br>Total_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Andorra","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Andorra","offsetgroup":"Andorra","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[105353]],"hovertemplate":"Country=Angola<br>Virus=%{x}<br>Percentage=%{y}<br>Total_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Angola","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Angola","offsetgroup":"Angola","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[3904]],"hovertemplate":"Country=Anguilla<br>Virus=%{x}<br>Percentage=%{y}<br>Total_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Anguilla","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Anguilla","offsetgroup":"Anguilla","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[9106]],"hovertemplate":"Country=Antigua and Barbuda<br>Virus=%{x}<br>Percentage=%{y}<br>Total_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Antigua and Barbuda","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Antigua and Barbuda","offsetgroup":"Antigua and Barbuda","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[448707]],"hovertemplate":"Country=Armenia<br>Virus=%{x}<br>Percentage=%{y}<br>Total_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Armenia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Armenia","offsetgroup":"Armenia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[44114]],"hovertemplate":"Country=Aruba<br>Virus=%{x}<br>Percentage=%{y}<br>Total_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Aruba","mar ...
# <div>                            <div id="ee72d6d3-fa4b-4595-b1c1-7837a5e9d7db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee72d6d3-fa4b-4595-b1c1-7837a5e9d7db")) {                    Plotly.newPlot(                        "ee72d6d3-fa4b-4595-b1c1-7837a5e9d7db",                        [{"alignmentgroup":"True","customdata":[[12009]],"hovertemplate":"Country=Afghanistan<br>Virus=%{x}<br>Percentage=%{y}<br>Active_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1693]],"hovertemplate":"Country=Albania<br>Virus=%{x}<br>Percentage=%{y}<br>Active_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Albania","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Albania","offsetgroup":"Albania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[81845]],"hovertemplate":"Country=Algeria<br>Virus=%{x}<br>Percentage=%{y}<br>Active_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Algeria","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Algeria","offsetgroup":"Algeria","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[211]],"hovertemplate":"Country=Andorra<br>Virus=%{x}<br>Percentage=%{y}<br>Active_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Andorra","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Andorra","offsetgroup":"Andorra","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[23]],"hovertemplate":"Country=Angola<br>Virus=%{x}<br>Percentage=%{y}<br>Active_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Angola","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Angola","offsetgroup":"Angola","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[13]],"hovertemplate":"Country=Anguilla<br>Virus=%{x}<br>Percentage=%{y}<br>Active_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Anguilla","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Anguilla","offsetgroup":"Anguilla","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[6]],"hovertemplate":"Country=Antigua and Barbuda<br>Virus=%{x}<br>Percentage=%{y}<br>Active_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Antigua and Barbuda","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Antigua and Barbuda","offsetgroup":"Antigua and Barbuda","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[4802]],"hovertemplate":"Country=Armenia<br>Virus=%{x}<br>Percentage=%{y}<br>Active_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Armenia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Armenia","offsetgroup":"Armenia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1440]],"hovertemplate":"Country=Aruba<br>Virus=%{x}<br>Percentage=%{y}<br>Active_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Aruba","marker":{"co ...
# <div>                            <div id="584fd78a-cb48-4373-a8d6-683b03289922" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("584fd78a-cb48-4373-a8d6-683b03289922")) {                    Plotly.newPlot(                        "584fd78a-cb48-4373-a8d6-683b03289922",                        [{"alignmentgroup":"True","customdata":[[198.0]],"hovertemplate":"Country=Afghanistan<br>Virus=%{x}<br>Percentage=%{y}<br>New_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[13.0]],"hovertemplate":"Country=Albania<br>Virus=%{x}<br>Percentage=%{y}<br>New_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Albania","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Albania","offsetgroup":"Albania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[7.0]],"hovertemplate":"Country=Algeria<br>Virus=%{x}<br>Percentage=%{y}<br>New_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Algeria","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Algeria","offsetgroup":"Algeria","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-1.0]],"hovertemplate":"Country=Andorra<br>Virus=%{x}<br>Percentage=%{y}<br>New_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Andorra","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Andorra","offsetgroup":"Andorra","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[-0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-1.0]],"hovertemplate":"Country=Angola<br>Virus=%{x}<br>Percentage=%{y}<br>New_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Angola","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Angola","offsetgroup":"Angola","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[-0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-1.0]],"hovertemplate":"Country=Anguilla<br>Virus=%{x}<br>Percentage=%{y}<br>New_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Anguilla","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Anguilla","offsetgroup":"Anguilla","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[-0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-1.0]],"hovertemplate":"Country=Antigua and Barbuda<br>Virus=%{x}<br>Percentage=%{y}<br>New_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Antigua and Barbuda","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Antigua and Barbuda","offsetgroup":"Antigua and Barbuda","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[-0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-1.0]],"hovertemplate":"Country=Armenia<br>Virus=%{x}<br>Percentage=%{y}<br>New_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Armenia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Armenia","offsetgroup":"Armenia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[-0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-1.0]],"hovertemplate":"Country=Aruba<br>Virus=%{x}<br>Percentage=%{y}<br>New_Cases=%{customdata[0]}<extra></extra>","legendgroup":"Aruba","marker":{"color":"#FF97FF"," ...
# <div>                            <div id="0afdc023-3526-4da9-b2ee-98218bdf7512" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0afdc023-3526-4da9-b2ee-98218bdf7512")) {                    Plotly.newPlot(                        "0afdc023-3526-4da9-b2ee-98218bdf7512",                        [{"alignmentgroup":"True","customdata":[[45]],"hovertemplate":"Country=Afghanistan<br>Virus=%{x}<br>Percentage=%{y}<br>Serious=%{customdata[0]}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-1]],"hovertemplate":"Country=Albania<br>Virus=%{x}<br>Percentage=%{y}<br>Serious=%{customdata[0]}<extra></extra>","legendgroup":"Albania","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Albania","offsetgroup":"Albania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[-0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-1]],"hovertemplate":"Country=Algeria<br>Virus=%{x}<br>Percentage=%{y}<br>Serious=%{customdata[0]}<extra></extra>","legendgroup":"Algeria","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Algeria","offsetgroup":"Algeria","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[-0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[14]],"hovertemplate":"Country=Andorra<br>Virus=%{x}<br>Percentage=%{y}<br>Serious=%{customdata[0]}<extra></extra>","legendgroup":"Andorra","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Andorra","offsetgroup":"Andorra","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-1]],"hovertemplate":"Country=Angola<br>Virus=%{x}<br>Percentage=%{y}<br>Serious=%{customdata[0]}<extra></extra>","legendgroup":"Angola","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Angola","offsetgroup":"Angola","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[-0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[4]],"hovertemplate":"Country=Anguilla<br>Virus=%{x}<br>Percentage=%{y}<br>Serious=%{customdata[0]}<extra></extra>","legendgroup":"Anguilla","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Anguilla","offsetgroup":"Anguilla","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1]],"hovertemplate":"Country=Antigua and Barbuda<br>Virus=%{x}<br>Percentage=%{y}<br>Serious=%{customdata[0]}<extra></extra>","legendgroup":"Antigua and Barbuda","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Antigua and Barbuda","offsetgroup":"Antigua and Barbuda","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[-1]],"hovertemplate":"Country=Armenia<br>Virus=%{x}<br>Percentage=%{y}<br>Serious=%{customdata[0]}<extra></extra>","legendgroup":"Armenia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Armenia","offsetgroup":"Armenia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[-0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[2]],"hovertemplate":"Country=Aruba<br>Virus=%{x}<br>Percentage=%{y}<br>Serious=%{customdata[0]}<extra></extra>","legendgroup":"Aruba","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Aruba","o ...
# <div>                            <div id="ed86005d-3189-4637-9b34-f925e5117553" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ed86005d-3189-4637-9b34-f925e5117553")) {                    Plotly.newPlot(                        "ed86005d-3189-4637-9b34-f925e5117553",                        [{"alignmentgroup":"True","customdata":[[5217.0]],"hovertemplate":"Country=Afghanistan<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/ 1M ppl=%{customdata[0]}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[116773.0]],"hovertemplate":"Country=Albania<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/ 1M ppl=%{customdata[0]}<extra></extra>","legendgroup":"Albania","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Albania","offsetgroup":"Albania","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[5990.0]],"hovertemplate":"Country=Algeria<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/ 1M ppl=%{customdata[0]}<extra></extra>","legendgroup":"Algeria","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Algeria","offsetgroup":"Algeria","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[618863.0]],"hovertemplate":"Country=Andorra<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/ 1M ppl=%{customdata[0]}<extra></extra>","legendgroup":"Andorra","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Andorra","offsetgroup":"Andorra","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.01],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[3008.0]],"hovertemplate":"Country=Angola<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/ 1M ppl=%{customdata[0]}<extra></extra>","legendgroup":"Angola","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Angola","offsetgroup":"Angola","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[256336.0]],"hovertemplate":"Country=Anguilla<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/ 1M ppl=%{customdata[0]}<extra></extra>","legendgroup":"Anguilla","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Anguilla","offsetgroup":"Anguilla","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.01],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[91509.0]],"hovertemplate":"Country=Antigua and Barbuda<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/ 1M ppl=%{customdata[0]}<extra></extra>","legendgroup":"Antigua and Barbuda","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Antigua and Barbuda","offsetgroup":"Antigua and Barbuda","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[150980.0]],"hovertemplate":"Country=Armenia<br>Virus=%{x}<br>Percentage=%{y}<br>Tot Cases/ 1M ppl=%{customdata[0]}<extra></extra>","legendgroup":"Armenia","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Armenia","offsetgroup":"Armenia","orientation":"v","showlegend":true,"textposition":"auto","x":["Covid-19"],"xaxis":"x","y":[0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[409947.0]],"hovertemplate":"Country=Aruba<br>Virus=%{x}<br>Percentage=%{y}<br>Tot  ...

# %%
df_countries.columns
# Out:
# Index(['Country', 'Total_Cases', 'New_Cases', 'Total_Deaths', 'New_Deaths',
#        'Total_Recovered', 'New_Recovered', 'Active_Cases', 'Serious',
#        'Tot Cases/ 1M ppl', 'Deaths/ 1M ppl', 'Total_Tests', 'Tests/ 1M ppl',
#        'Population', 'Continent', '% Inc_Cases', '% Inc_Deaths',
#        '% Inc_Recovered'],
#       dtype='object')

# %% [markdown]
# #### For Top 5 or 10 Countries:

# %%
df2 = df1.drop([len(df1)-1]) #drop last row "Total".
country_df = df2.drop([0])

# %%
country_df.head()
# Out:
#    Country  Total_Cases  New_Cases  Total_Deaths  New_Deaths  Total_Recovered
# 1      USA    106464679     1098.0       1158158         8.0        104311698  \
# 2    India     44818115    10093.0        531114        23.0         44229459
# 3   France     39896203     8595.0        166024        -1.0         39592740
# 4  Germany     38382386       -1.0        171992        -1.0         38149200
# 5   Brazil     37358092       -1.0        700811        -1.0         36249161
#
#    New_Recovered  Active_Cases  Serious  Tot Cases/ 1M ppl  Deaths/ 1M ppl
# 1         9159.0        994823     1636           317990.0          3459.0  \
# 2         6248.0         57542        0            31862.0           378.0
# 3         6103.0        137439      869           608317.0          2531.0
# 4         1200.0         61194        0           457567.0          2050.0
# 5           -1.0        408120        0           173473.0          3254.0
#
#    Total_Tests  Tests/ 1M ppl  Population      Continent  % Inc_Cases
# 1   1175946071        3512328   334805269  North America     0.001031  \
# 2    923877832         656801  1406631776           Asia     0.022520
# 3    271490188        4139547    65584518         Europe     0.021543
# 4    122332384        1458359    83883596         Europe    -0.000003
# 5     63776166         296146   215353593  South America    -0.000003
#
#    % Inc_Deaths  % Inc_Recovered
# 1      0.000691         0.008780
# 2      0.004331         0.014126
# 3     -0.000602         0.015414
# 4     -0.000581         0.003146
# 5     -0.000143        -0.000003

# %%
LOOK_AT = 5
country = country_df.columns[1:14]
fig = go.Figure()
c = 0
for i in country_df.index:
    if c < LOOK_AT:
        fig.add_trace(go.Bar(name = country_df['Country'][i], x = country, y = country_df.loc[i][1:14]))
    else:
        break
    c +=1
fig.update_layout(title = {"text":f'top {LOOK_AT} countries affected '}, yaxis_type = "log")
fig.show()
# Out:
# <div>                            <div id="c90ece44-6fab-4dad-bf8e-97b91127295f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c90ece44-6fab-4dad-bf8e-97b91127295f")) {                    Plotly.newPlot(                        "c90ece44-6fab-4dad-bf8e-97b91127295f",                        [{"name":"USA","x":["Total_Cases","New_Cases","Total_Deaths","New_Deaths","Total_Recovered","New_Recovered","Active_Cases","Serious","Tot Cases/ 1M ppl","Deaths/ 1M ppl","Total_Tests","Tests/ 1M ppl","Population"],"y":[106464679,1098.0,1158158,8.0,104311698,9159.0,994823,1636,317990.0,3459.0,1175946071,3512328,334805269],"type":"bar"},{"name":"India","x":["Total_Cases","New_Cases","Total_Deaths","New_Deaths","Total_Recovered","New_Recovered","Active_Cases","Serious","Tot Cases/ 1M ppl","Deaths/ 1M ppl","Total_Tests","Tests/ 1M ppl","Population"],"y":[44818115,10093.0,531114,23.0,44229459,6248.0,57542,0,31862.0,378.0,923877832,656801,1406631776],"type":"bar"},{"name":"France","x":["Total_Cases","New_Cases","Total_Deaths","New_Deaths","Total_Recovered","New_Recovered","Active_Cases","Serious","Tot Cases/ 1M ppl","Deaths/ 1M ppl","Total_Tests","Tests/ 1M ppl","Population"],"y":[39896203,8595.0,166024,-1.0,39592740,6103.0,137439,869,608317.0,2531.0,271490188,4139547,65584518],"type":"bar"},{"name":"Germany","x":["Total_Cases","New_Cases","Total_Deaths","New_Deaths","Total_Recovered","New_Recovered","Active_Cases","Serious","Tot Cases/ 1M ppl","Deaths/ 1M ppl","Total_Tests","Tests/ 1M ppl","Population"],"y":[38382386,-1.0,171992,-1.0,38149200,1200.0,61194,0,457567.0,2050.0,122332384,1458359,83883596],"type":"bar"},{"name":"Brazil","x":["Total_Cases","New_Cases","Total_Deaths","New_Deaths","Total_Recovered","New_Recovered","Active_Cases","Serious","Tot Cases/ 1M ppl","Deaths/ 1M ppl","Total_Tests","Tests/ 1M ppl","Population"],"y":[37358092,-1.0,700811,-1.0,36249161,-1.0,408120,0,173473.0,3254.0,63776166,296146,215353593],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0 ...
